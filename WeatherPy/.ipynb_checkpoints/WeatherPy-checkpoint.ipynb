# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
# api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={your api key} 
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# cities

# %%
set_counter = 1
record_counter = 0
df_columns = ['City', 'Lat' , 'Lng',
                'Max Temp', 'Humidity',
                'Cloudiness','Wind Speed',
                'Country', 'Date']
city_data_list = []
for city in cities:
    try:
        url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
        city_data = requests.get(url).json()
        print(f'Processing Record {record_counter} of Set {set_counter} | {city}')
        city_data_list.append([city,city_data['coord']['lat'],city_data['coord']['lon'],
                               city_data['main']['temp_max'],city_data['main']['humidity'],
                               city_data['clouds']['all'], city_data['wind']['speed'],
                               city_data['sys']['country'],city_data['dt']])
    except:
        print('City not found. Skipping...')
        print(city_data)
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
#     weather_dict['City'].append()
    if record_counter == 49:
        record_counter = 0
        set_counter += 1
    record_counter +=1
#     break
citydf = pd.DataFrame(np.array(city_data_list),columns =df_columns)
# Out:
# Processing Record 0 of Set 1 | marcona
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | san andres
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 5 of Set 1 | simao
# Processing Record 6 of Set 1 | kudahuvadhoo
# Processing Record 7 of Set 1 | tagusao
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | mendi
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | atsiki
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 12 of Set 1 | ahipara
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | drumheller
# Processing Record 15 of Set 1 | samarai
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | kochubey
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | sur
# Processing Record 26 of Set 1 | rong kwang
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | cayenne
# Processing Record 30 of Set 1 | arawa
# Processing Record 31 of Set 1 | tuggurt
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 32 of Set 1 | grimshaw
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | san lazaro
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | doha
# Processing Record 38 of Set 1 | akhmim
# Processing Record 39 of Set 1 | mayumba
# Processing Record 40 of Set 1 | yuyao
# Processing Record 41 of Set 1 | hobyo
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | wonthaggi
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 47 of Set 1 | tessalit
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | port alfred
# Processing Record 1 of Set 2 | nishihara
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | richards bay
# Processing Record 5 of Set 2 | zhuhai
# Processing Record 6 of Set 2 | hanzhong
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | zhob
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | abnub
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | sefophe
# Processing Record 17 of Set 2 | xinmin
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | yudong
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | san nicolas
# Processing Record 24 of Set 2 | antofagasta
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | roma
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | nara
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | karamea
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | iranshahr
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | mangaldai
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | cabinda
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | kysyl-syr
# Processing Record 45 of Set 2 | srednekolymsk
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | prado
# Processing Record 2 of Set 3 | tiruvottiyur
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 2 of Set 5 | erenhot
# Processing Record 3 of Set 5 | aklavik
# Processing Record 4 of Set 5 | peniche
# Processing Record 5 of Set 5 | dalbandin
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | lac du bonnet
# Processing Record 9 of Set 5 | lamu
# Processing Record 10 of Set 5 | shenjiamen
# Processing Record 11 of Set 5 | hidrolandia
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | troitskoye
# Processing Record 14 of Set 5 | mizdah
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | wickford
# Processing Record 17 of Set 5 | normandin
# Processing Record 18 of Set 5 | el calvario
# Processing Record 19 of Set 5 | salinopolis
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | aflu
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 22 of Set 5 | bubaque
# Processing Record 23 of Set 5 | ucluelet
# Processing Record 24 of Set 5 | hailun
# Processing Record 25 of Set 5 | rafai
# Processing Record 26 of Set 5 | flagstaff
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | eyemouth
# Processing Record 29 of Set 5 | virginia beach
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | isiro
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | menongue
# Processing Record 35 of Set 5 | kemi
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | tiarei
# Processing Record 38 of Set 5 | caetite
# Processing Record 39 of Set 5 | olafsvik
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | meyungs
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 42 of Set 5 | marystown
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | oak harbor
# Processing Record 45 of Set 5 | port moresby
# Processing Record 46 of Set 5 | nykobing
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | huarmey
# Processing Record 49 of Set 5 | pisco
# Processing Record 1 of Set 6 | bauchi
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | springdale
# Processing Record 5 of Set 6 | vytegra
# Processing Record 6 of Set 6 | bairiki
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | gangotri
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | pangai
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | abalak
# Processing Record 13 of Set 6 | grand gaube
# Processing Record 14 of Set 6 | bambous virieux
# Processing Record 15 of Set 6 | moreira sales
# Processing Record 16 of Set 6 | pachino
# Processing Record 17 of Set 6 | nalut
# Processing Record 18 of Set 6 | sabha
# Processing Record 19 of Set 6 | shingu
# Processing Record 20 of Set 6 | kyrksaeterora
# Processing Record 21 of Set 6 | hofn
# Processing Record 22 of Set 6 | padang
# Processing Record 23 of Set 6 | sioux lookout
# Processing Record 24 of Set 6 | conceicao da barra
# Processing Record 25 of Set 6 | avarua
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | attawapiskat
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 28 of Set 6 | orleans
# Processing Record 29 of Set 6 | beloha
# Processing Record 30 of Set 6 | lolua
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 6 | prokhorovka
# Processing Record 32 of Set 6 | talawdi
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 33 of Set 6 | marsh harbour
# Processing Record 34 of Set 6 | albolote
# Processing Record 35 of Set 6 | augusto correa
# Processing Record 36 of Set 6 | bekwai
# Processing Record 37 of Set 6 | durban
# Processing Record 38 of Set 6 | port lincoln
# Processing Record 39 of Set 6 | shimoda
# Processing Record 40 of Set 6 | tasiilaq
# Processing Record 41 of Set 6 | severodvinsk
# Processing Record 42 of Set 6 | los llanos de aridane
# Processing Record 43 of Set 6 | tabiauea
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 44 of Set 6 | noumea
# Processing Record 45 of Set 6 | abay
# Processing Record 46 of Set 6 | port said
# Processing Record 47 of Set 6 | prince george
# Processing Record 48 of Set 6 | grand river south east
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 49 of Set 6 | camabatela
# Processing Record 1 of Set 7 | ojinaga
# Processing Record 2 of Set 7 | nanakuli
# Processing Record 3 of Set 7 | teya
# Processing Record 4 of Set 7 | cheuskiny
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 5 of Set 7 | ribeira grande
# Processing Record 6 of Set 7 | sikonge
# Processing Record 7 of Set 7 | port hardy
# Processing Record 8 of Set 7 | togitsu
# Processing Record 9 of Set 7 | bojnurd
# Processing Record 10 of Set 7 | chongwe
# Processing Record 11 of Set 7 | touros
# Processing Record 12 of Set 7 | san ignacio
# Processing Record 13 of Set 7 | sao joaquim do monte
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | louisbourg
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 16 of Set 7 | verkhnevilyuysk
# Processing Record 17 of Set 7 | fukue
# Processing Record 18 of Set 7 | chipurupalle
# Processing Record 19 of Set 7 | brenham
# Processing Record 20 of Set 7 | erdemli
# Processing Record 21 of Set 7 | zomin
# Processing Record 22 of Set 7 | tacuarembo
# Processing Record 23 of Set 7 | santiago de cao
# Processing Record 24 of Set 7 | belushya guba
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 25 of Set 7 | gucheng
# Processing Record 26 of Set 7 | keffi
# Processing Record 27 of Set 7 | ilhabela
# Processing Record 28 of Set 7 | victor harbor
# Processing Record 29 of Set 7 | yurla
# Processing Record 30 of Set 7 | mayor pablo lagerenza
# Processing Record 31 of Set 7 | novovasylivka
# Processing Record 32 of Set 7 | chitrakonda
# Processing Record 33 of Set 7 | jijiga
# Processing Record 34 of Set 7 | nilanga
# Processing Record 35 of Set 7 | launceston
# Processing Record 36 of Set 7 | sobolevo
# Processing Record 37 of Set 7 | lata
# Processing Record 38 of Set 7 | ballina
# Processing Record 39 of Set 7 | mtimbira
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | airai
# Processing Record 42 of Set 7 | rocha
# Processing Record 43 of Set 7 | khani
# Processing Record 44 of Set 7 | opuwo
# Processing Record 45 of Set 7 | redlands
# Processing Record 46 of Set 7 | tuban
# Processing Record 47 of Set 7 | puerto narino
# Processing Record 48 of Set 7 | luderitz
# Processing Record 49 of Set 7 | djambala
# Processing Record 1 of Set 8 | maarianhamina
# Processing Record 2 of Set 8 | cam ranh
# Processing Record 3 of Set 8 | port macquarie
# Processing Record 4 of Set 8 | gurskoye
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 30 of Set 9 | umm durman
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 31 of Set 9 | atherton
# Processing Record 32 of Set 9 | hunza
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 33 of Set 9 | saint-francois
# Processing Record 34 of Set 9 | shalazhi
# Processing Record 35 of Set 9 | kenora
# Processing Record 36 of Set 9 | kungurtug
# Processing Record 37 of Set 9 | jasper
# Processing Record 38 of Set 9 | cockburn town
# Processing Record 39 of Set 9 | bukama
# Processing Record 40 of Set 9 | cabatuan
# Processing Record 41 of Set 9 | labrea
# Processing Record 42 of Set 9 | merauke
# Processing Record 43 of Set 9 | san javier
# Processing Record 44 of Set 9 | mana
# Processing Record 45 of Set 9 | labuan
# Processing Record 46 of Set 9 | auki
# Processing Record 47 of Set 9 | dong hoi
# Processing Record 48 of Set 9 | sept-iles
# Processing Record 49 of Set 9 | davila
# Processing Record 1 of Set 10 | sungaipenuh
# Processing Record 2 of Set 10 | karratha
# Processing Record 3 of Set 10 | tabuk
# Processing Record 4 of Set 10 | rincon
# Processing Record 5 of Set 10 | halifax
# Processing Record 6 of Set 10 | zlatoustovsk
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 7 of Set 10 | mackenzie
# Processing Record 8 of Set 10 | vientiane
# Processing Record 9 of Set 10 | tongliao
# Processing Record 10 of Set 10 | margate
# Processing Record 11 of Set 10 | walvis bay
# Processing Record 12 of Set 10 | manado
# Processing Record 13 of Set 10 | najran
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | banyo
# Processing Record 16 of Set 10 | narsaq
# Processing Record 17 of Set 10 | chiredzi
# Processing Record 18 of Set 10 | orlik
# Processing Record 19 of Set 10 | corinto
# Processing Record 20 of Set 10 | taywarah
# Processing Record 21 of Set 10 | palabuhanratu
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | odoyev
# Processing Record 24 of Set 10 | almaznyy
# Processing Record 25 of Set 10 | non thai
# Processing Record 26 of Set 10 | kendari
# Processing Record 27 of Set 10 | luancheng
# Processing Record 28 of Set 10 | lasa
# Processing Record 29 of Set 10 | mumford
# Processing Record 30 of Set 10 | gari
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | vardo
# Processing Record 33 of Set 10 | trairi
# Processing Record 34 of Set 10 | coolum beach
# Processing Record 35 of Set 10 | tullahoma
# Processing Record 36 of Set 10 | atsipopoulon
# Processing Record 37 of Set 10 | starchiojd
# Processing Record 38 of Set 10 | vao
# Processing Record 39 of Set 10 | ondorhaan
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 40 of Set 10 | pemangkat
# Processing Record 41 of Set 10 | arraial do cabo
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | bontang
# Processing Record 44 of Set 10 | morros
# Processing Record 45 of Set 10 | leon
# Processing Record 46 of Set 10 | anloga
# Processing Record 47 of Set 10 | malwan
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 48 of Set 10 | tarudant
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 49 of Set 10 | yulara
# Processing Record 1 of Set 11 | kutum
# Processing Record 2 of Set 11 | emboscada
# Processing Record 3 of Set 11 | mysliborz
# Processing Record 4 of Set 11 | san luis
# Processing Record 5 of Set 11 | abu kamal
# Processing Record 6 of Set 11 | ambeliai
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 7 of Set 11 | porto walter
# Processing Record 8 of Set 11 | sarangani
# Processing Record 9 of Set 11 | turka
# Processing Record 10 of Set 11 | mazagao
# Processing Record 11 of Set 11 | havoysund
# Processing Record 12 of Set 11 | middle island
# Processing Record 13 of Set 11 | yumen
# Processing Record 14 of Set 11 | qaqortoq
# Processing Record 15 of Set 11 | saint anthony
# Processing Record 16 of Set 11 | emerald
# Processing Record 17 of Set 11 | aljezur
# Processing Record 18 of Set 11 | masuguru
# Processing Record 19 of Set 11 | kondinskoye
# Processing Record 20 of Set 11 | westport
# Processing Record 21 of Set 11 | strezhevoy
# Processing Record 22 of Set 11 | kijang
# Processing Record 23 of Set 11 | san quintin
# Processing Record 24 of Set 11 | college
# Processing Record 25 of Set 11 | byron bay
# Processing Record 26 of Set 11 | turukhansk
# Processing Record 27 of Set 11 | sunagawa
# Processing Record 28 of Set 11 | den helder
# Processing Record 29 of Set 11 | eureka
# Processing Record 30 of Set 11 | constitucion
# Processing Record 31 of Set 11 | svirsk
# Processing Record 32 of Set 11 | vanimo
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | sao jose da coroa grande
# Processing Record 35 of Set 11 | jackson
# Processing Record 36 of Set 11 | purificacion
# Processing Record 37 of Set 11 | cururupu
# Processing Record 38 of Set 11 | erzin
# Processing Record 39 of Set 11 | ampanihy
# Processing Record 40 of Set 11 | nuuk
# Processing Record 41 of Set 11 | moose factory
# Processing Record 42 of Set 11 | carovigno
# Processing Record 43 of Set 11 | sorland
# Processing Record 44 of Set 11 | sun prairie
# Processing Record 45 of Set 11 | sangamner
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | barashevo
# Processing Record 48 of Set 11 | coihaique
# Processing Record 49 of Set 11 | taltal
# Processing Record 1 of Set 12 | sinnamary
# Processing Record 2 of Set 12 | inhambane
# Processing Record 3 of Set 12 | zhangye
# Processing Record 4 of Set 12 | winder
# Processing Record 5 of Set 12 | clovis
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | sile
# Processing Record 8 of Set 12 | rajpur
# Processing Record 9 of Set 12 | manoel urbano
# Processing Record 10 of Set 12 | ivankiv
# Processing Record 11 of Set 12 | belousovka
# Processing Record 12 of Set 12 | kavaratti
# Processing Record 13 of Set 12 | porto murtinho
# Processing Record 14 of Set 12 | angra
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 15 of Set 12 | gwanda
# Processing Record 16 of Set 12 | salalah
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | shirokiy
# Processing Record 19 of Set 12 | hurghada
# Processing Record 20 of Set 12 | ambulu
# Processing Record 21 of Set 12 | lujan
# Processing Record 22 of Set 12 | wloszczowa
# Processing Record 23 of Set 12 | tsihombe
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 24 of Set 12 | samusu
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | kajaani
# Processing Record 27 of Set 12 | mayo
# Processing Record 28 of Set 12 | mabaruma
# Processing Record 29 of Set 12 | yar-sale
# Processing Record 30 of Set 12 | omboue
# Processing Record 31 of Set 12 | acuitzio
# Processing Record 32 of Set 12 | danane
# Processing Record 33 of Set 12 | kaa-khem
# Processing Record 34 of Set 12 | sao felix do xingu
# Processing Record 35 of Set 12 | atasu
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | duz
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 38 of Set 12 | imeni poliny osipenko
# Processing Record 39 of Set 12 | andros town
# Processing Record 40 of Set 12 | mangrol
# Processing Record 41 of Set 12 | soyo
# Processing Record 42 of Set 12 | gorontalo
# Processing Record 43 of Set 12 | ust-kan
# Processing Record 44 of Set 12 | kwinana
# Processing Record 45 of Set 12 | jiazi
# Processing Record 46 of Set 12 | tahta
# Processing Record 47 of Set 12 | parys
# Processing Record 48 of Set 12 | santiago
# Processing Record 49 of Set 12 | wajir
# Processing Record 1 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 2 of Set 13 | kyabram
# Processing Record 3 of Set 13 | batsfjord
# Processing Record 4 of Set 13 | belaya gora
# Processing Record 5 of Set 13 | abu jubayhah
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 6 of Set 13 | mirnyy
# Processing Record 7 of Set 13 | gouyave
# Processing Record 8 of Set 13 | yenagoa
# Processing Record 9 of Set 13 | les cayes
# Processing Record 10 of Set 13 | zupanja
# Processing Record 11 of Set 13 | ivanava
# Processing Record 12 of Set 13 | samalaeulu
# City not found. Skipping...
# {'cod': '404', 'message': 'city not found'}
# Processing Record 13 of Set 13 | muriti
# Processing Record 14 of Set 13 | maamba
# Processing Record 15 of Set 13 | leirvik
# Processing Record 16 of Set 13 | chimbote
# Processing Record 17 of Set 13 | plouzane
# Processing Record 18 of Set 13 | svetlogorsk
# Processing Record 19 of Set 13 | tilichiki

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydf['Lat'] = citydf['Lat'].astype(float)
citydf['Lng'] = citydf['Lng'].astype(float)
citydf['Max Temp'] = citydf['Max Temp'].astype(float)
citydf['Humidity'] = citydf['Humidity'].astype(float)
citydf['Cloudiness'] = citydf['Cloudiness'].astype(float)
citydf['Wind Speed'] = citydf['Wind Speed'].astype(float)
citydf.count()
# Out:
# City          552
# Lat           552
# Lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# Date          552
# dtype: int64

# %%
citydf.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          hilo  19.73 -155.09     29.00      54.0        90.0        4.10
# 1    san andres  12.58  -81.70     31.00      70.0        20.0        4.10
# 2    bredasdorp -34.53   20.04      5.00      93.0         0.0        1.50
# 3         simao  22.79  100.97     17.06      94.0         9.0        0.58
# 4  kudahuvadhoo   2.67   72.89     27.94      75.0        94.0        4.51
#
#   Country        Date
# 0      US  1595888170
# 1      CO  1595888171
# 2      ZA  1595888171
# 3      CN  1595888171
# 4      MV  1595888171

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
too_hum_index = citydf.loc[citydf['Humidity'] >= 100].index

#  Get the indices of cities that have humidity over 100%.
# too_hum_index
citydf.iloc[:,1:7].describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  552.000000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean    18.568261   19.835471   20.761069   72.329710   47.219203    3.392464
# std     32.813452   89.309095    7.947616   19.207341   38.186819    2.182175
# min    -54.800000 -175.200000    1.000000    1.000000    0.000000    0.100000
# 25%     -8.440000  -58.065000   14.920000   62.750000    5.750000    1.840000
# 50%     21.255000   24.775000   22.000000   77.000000   40.000000    2.955000
# 75%     46.915000  100.375000   26.670000   87.000000   86.000000    4.600000
# max     78.220000  179.320000   39.000000  100.000000  100.000000   11.620000

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = citydf.drop(too_hum_index, inplace = False)
clean_city_data.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          hilo  19.73 -155.09     29.00      54.0        90.0        4.10
# 1    san andres  12.58  -81.70     31.00      70.0        20.0        4.10
# 2    bredasdorp -34.53   20.04      5.00      93.0         0.0        1.50
# 3         simao  22.79  100.97     17.06      94.0         9.0        0.58
# 4  kudahuvadhoo   2.67   72.89     27.94      75.0        94.0        4.51
#
#   Country        Date
# 0      US  1595888170
# 1      CO  1595888171
# 2      ZA  1595888171
# 3      CN  1595888171
# 4      MV  1595888171

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
clean_city_data[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']].to_csv('City_Data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data = pd.read_csv('City_Data.csv')
today =datetime.date.today().strftime("%m/%d/%Y")
heatValue = clean_city_data['Max Temp']

clean_city_data.plot('Lat','Max Temp',kind= 'scatter',title = f'City Latitude vs. Max Temperature {today}',
                    grid = True, edgecolors="black",c = heatValue,cmap = 'coolwarm', s =35)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
heatValue = clean_city_data['Humidity']
clean_city_data.plot('Lat','Humidity',kind= 'scatter',title = f'City Latitude vs. Humidity {today}',
                    grid = True, edgecolors="black",c = heatValue,cmap = 'Blues', s =35)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
heatValue = clean_city_data['Cloudiness']
clean_city_data.plot('Lat','Cloudiness',kind= 'scatter',title = f'City Latitude vs. Cloudiness {today}',
                    grid = True, edgecolors="black",c = heatValue, s =35)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
heatValue = clean_city_data['Wind Speed']
clean_city_data.plot('Lat','Wind Speed',kind= 'scatter',title = f'City Latitude vs. Wind Speed {today}',
                    grid = True, edgecolors="black",c = heatValue,cmap = 'Greens', s =35)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern = clean_city_data.loc[clean_city_data['Lat'] >= 0]
southern = clean_city_data.loc[clean_city_data['Lat'] <= 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,northern['Lat'].min()+5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
# plt.ylim(0,90)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.42475867409845264

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(southern['Lat'].max()-25,5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.655006040786402

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,southern['Lat'].max()+5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.007276325578506132

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(southern['Lat'].max()-25,5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.00028660425146534007

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,southern['Lat'].max()+5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.013566857881750665

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(southern['Lat'].min()+5,5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.009473317470601804

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern['Lat']
y_values = northern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(northern['Lat'].max()-50,northern['Wind Speed'].max()-1),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-squared is: 1.3928029886776332e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern['Lat']
y_values = southern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(southern['Lat'].min()+5,5),fontsize=15,color="red")
print(f'The r-squared is: {rvalue**2}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-squared is: 0.0003841567680943469
